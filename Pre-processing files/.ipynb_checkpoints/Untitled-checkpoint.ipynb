# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow as tf

# Define directories
train_dir = 'data/train'
val_dir = 'data/val'
test_dir = 'data/test'

# Image size and channels
img_size = (256, 256)
channels = 3
# Save the trained model
model.save('skin_cancer_model_final.keras')
# Batch size and epochs
batch_size = 32
epochs = 20

# For using GPUS
gpus = tf.config.experimental.list_physical_devices('GPU') # Listing GPUs
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu,True)
    
# Data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)

# Load dataset
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary'
)

# Build CNN model
model = Sequential()
#model.add(Conv2D(#filters,#filter-size, stride, activation='relu'))
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())

model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())

# Add Dense layer with L2 regularization
model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.5))

# Add Dense layer with L2 regularization and sigmoid activation for binary classification
model.add(Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)))

model.compile(optimizer=Adam(lr=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# Model callbacks
checkpoint = ModelCheckpoint('skin_cancer_model.h5', save_best_only=True)
early_stopping = EarlyStopping(patience=10, restore_best_weights=True)

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=val_generator,
    validation_steps=val_generator.samples // batch_size,
    callbacks=[checkpoint, early_stopping]
)

# Plot training history
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Evaluate the model on test set
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

# Confusion matrix and classification report
Y_pred = model.predict_generator(test_generator, test_generator.samples // batch_size + 1)
Y_pred = np.round(Y_pred)
Y_true = test_generator.classes

conf_matrix = confusion_matrix(Y_true, Y_pred)
class_report = classification_report(Y_true, Y_pred, target_names=train_generator.class_indices)

print("Confusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)

# Test an image
from tensorflow.keras.preprocessing import image

def load_and_predict(image_path):
    img = image.load_img(image_path, target_size=img_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.

    prediction = model.predict(img_array)
    if prediction[0] > 0.5:
        print("Malignant")
    else:
        print("Benign")

# Replace 'path/to/test_image.jpg' with the actual path to your test image
test_image_path = 'path/to/test_image.jpg'
load_and_predict(test_image_path)

# Save the trained model
model.save('skin_cancer_model_final.keras')
# Out:
# Found 60 images belonging to 2 classes.
# Found 60 images belonging to 2 classes.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/20
# 2023-11-22 18:53:32.932744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - ETA: 0s - loss: 5.7558 - accuracy: 0.4643
# 2023-11-22 18:53:34.045480: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - 2s 2s/step - loss: 5.7558 - accuracy: 0.4643 - val_loss: 5.9021 - val_accuracy: 0.5312
# Epoch 2/20
# 1/1 [==============================] - 1s 966ms/step - loss: 6.0310 - accuracy: 0.4375 - val_loss: 5.0446 - val_accuracy: 0.5312
# Epoch 3/20
# 1/1 [==============================] - 1s 948ms/step - loss: 5.0829 - accuracy: 0.5357 - val_loss: 4.6094 - val_accuracy: 0.4688
# Epoch 4/20
# 1/1 [==============================] - 1s 953ms/step - loss: 4.5200 - accuracy: 0.5714 - val_loss: 4.0038 - val_accuracy: 0.4375
# Epoch 5/20
# 1/1 [==============================] - 1s 906ms/step - loss: 3.9407 - accuracy: 0.4643 - val_loss: 3.5518 - val_accuracy: 0.4062
# Epoch 6/20
# 1/1 [==============================] - 1s 902ms/step - loss: 3.5974 - accuracy: 0.3438 - val_loss: 3.2123 - val_accuracy: 0.5000
# Epoch 7/20
# 1/1 [==============================] - 1s 969ms/step - loss: 3.2116 - accuracy: 0.5312 - val_loss: 2.9281 - val_accuracy: 0.4688
# Epoch 8/20
# 1/1 [==============================] - 1s 921ms/step - loss: 2.9231 - accuracy: 0.5000 - val_loss: 2.6746 - val_accuracy: 0.4688
# Epoch 9/20
# 1/1 [==============================] - 1s 901ms/step - loss: 2.6923 - accuracy: 0.3571 - val_loss: 2.4436 - val_accuracy: 0.5000
# Epoch 10/20
# 1/1 [==============================] - 1s 868ms/step - loss: 2.4512 - accuracy: 0.4643 - val_loss: 2.2533 - val_accuracy: 0.5000
# Epoch 11/20
# 1/1 [==============================] - 1s 965ms/step - loss: 2.2547 - accuracy: 0.4286 - val_loss: 2.0841 - val_accuracy: 0.6250
# Epoch 12/20
# 1/1 [==============================] - 1s 916ms/step - loss: 2.0857 - accuracy: 0.5312 - val_loss: 1.9451 - val_accuracy: 0.5000
# Epoch 13/20
# 1/1 [==============================] - 1s 954ms/step - loss: 1.9442 - accuracy: 0.6250 - val_loss: 1.8228 - val_accuracy: 0.5000
# Epoch 14/20
# 1/1 [==============================] - 1s 986ms/step - loss: 1.8240 - accuracy: 0.5000 - val_loss: 1.7151 - val_accuracy: 0.5625
# Epoch 15/20
# 1/1 [==============================] - 1s 951ms/step - loss: 1.7213 - accuracy: 0.5000 - val_loss: 1.6338 - val_accuracy: 0.4688
# Epoch 16/20
# 1/1 [==============================] - 1s 930ms/step - loss: 1.6323 - accuracy: 0.3929 - val_loss: 1.5583 - val_accuracy: 0.5312
# Epoch 17/20
# 1/1 [==============================] - 1s 968ms/step - loss: 1.5556 - accuracy: 0.4643 - val_loss: 1.4982 - val_accuracy: 0.5312
# Epoch 18/20
# 1/1 [==============================] - 1s 1s/step - loss: 1.4993 - accuracy: 0.5312 - val_loss: 1.4451 - val_accuracy: 0.5938
# Epoch 19/20
# 1/1 [==============================] - 1s 1s/step - loss: 1.4499 - accuracy: 0.5000 - val_loss: 1.4078 - val_accuracy: 0.4062
# Epoch 20/20
# 1/1 [==============================] - 1s 935ms/step - loss: 1.4073 - accuracy: 0.3929 - val_loss: 1.3741 - val_accuracy: 0.5000
# Found 60 images belonging to 2 classes.
# /tmp/ipykernel_44680/3866659712.py:121: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = model.predict_generator(test_generator, test_generator.samples // batch_size + 1)
# 2023-11-22 18:53:52.948209: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Confusion Matrix:
#  [[15 15]
#  [15 15]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.50      0.50      0.50        30
#    malignant       0.50      0.50      0.50        30
#
#     accuracy                           0.50        60
#    macro avg       0.50      0.50      0.50        60
# weighted avg       0.50      0.50      0.50        60
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 148
#     146 # Replace 'path/to/test_image.jpg' with the actual path to your test image
#     147 test_image_path = 'path/to/test_image.jpg'
# --> 148 load_and_predict(test_image_path)
#     150 # Save the trained model
#     151 model.save('skin_cancer_model_final.keras')
#
# Cell In[6], line 135, in load_and_predict(image_path)
#     134 def load_and_predict(image_path):
# --> 135     img = image.load_img(image_path, target_size=img_size)
#     136     img_array = image.img_to_array(img)
#     137     img_array = np.expand_dims(img_array, axis=0)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/keras/utils/image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path/to/test_image.jpg'
